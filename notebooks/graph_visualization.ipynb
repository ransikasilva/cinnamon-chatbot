# %%
import sys
from IPython import display

sys.path.append("../src")

from octave.chml.chatbot.backend.graph import graph_defs

# %%
def visualize_graph(graph):
    mermaid_code = graph.get_graph().draw_mermaid()
    display.display(display.Markdown(f"```mermaid\n{mermaid_code}\n```"))

# %%
graph = graph_defs.build_booking_graph({}, None)
visualize_graph(graph)
# Out:
# ```mermaid
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	extract_booking_info(extract_booking_info)
# 	check_destination(check_destination)
# 	check_property(check_property)
# 	check_booking_details(check_booking_details)
# 	finalize(finalize)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> extract_booking_info;
# 	check_booking_details -. &nbsp;ask_details&nbsp; .-> __end__;
# 	check_booking_details -.-> finalize;
# 	check_destination -. &nbsp;ask_destination&nbsp; .-> __end__;
# 	check_destination -.-> check_property;
# 	check_property -. &nbsp;ask_property&nbsp; .-> __end__;
# 	check_property -.-> check_booking_details;
# 	extract_booking_info --> check_destination;
# 	finalize --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc
#
# ```
